# %%
import numpy as np
import scipy.linalg as scipy

# %%
def new_rand_A(size_n, size_m):
    A = np.zeros((size_n,size_m))
    for i in range(size_n):
        for j in range(size_m):
            A[i][j] = np.random.randint(low=-9, high=9)
    
    return A

A_10 = new_rand_A(10,8)
A_100 = new_rand_A(100,100)

def secretly_rank_k(size_n, size_k):
    a = np.zeros((size_n,size_k))
    b = np.zeros((size_k, size_n))
    
    for i in range(size_n):
        for j in range(size_k):
            a[i][j] = np.random.randint(low=-9, high=9)
            b[j][i] = np.random.randint(low=-9, high=9)
            
    return np.matmul(a, b)

def pivot_A(A, p):
    new_A = np.zeros((len(A),len(A[0])))
    for col in range(len(p)):
        new_A[:,col] = A[:,p[col]]
    return new_A

S_100 = secretly_rank_k(100, 3)
Q,R,p = scipy.qr(A_10, pivoting=True)
u,s,v = np.linalg.svd(S_100)

# %%
'''TEST CELL, DISREGARD'''

'''diagonal = np.diagonal(R)
norm = np.linalg.norm(new_A, ord=2)
normR = np.linalg.norm(R, ord=2)
print(norm, normR)
print(np.linalg.matrix_rank())
S = secretly_rank_k(10, 3)'''

'''A = new_rand_A(10,5)
Q,R,p = scipy.qr(A, pivoting=True)
piv_A = pivot_A(A,p)
r_11 = R[0,0]
r_12 = R[0,1:]
r_22 = R[1:,1:]

print(Q)
q_1 = Q[:,:2]
q_2 = Q[:,2:]
print(q_1)
print(q_2)'''

'''Q,R,p = scipy.qr(A_10, pivoting=True)
pivoted_A = pivot_A(A_10,p)
print(np.diagonal(pivoted_A))
QR = np.matmul(Q,R)
print(np.linalg.norm(pivoted_A, ord=2))
print(np.linalg.norm(QR, ord=2))
print(np.linalg.norm(pivoted_A - QR, ord=2))'''
# Out:
# 'Q,R,p = scipy.qr(A_10, pivoting=True)\npivoted_A = pivot_A(A_10,p)\nprint(np.diagonal(pivoted_A))\nQR = np.matmul(Q,R)\nprint(np.linalg.norm(pivoted_A, ord=2))\nprint(np.linalg.norm(QR, ord=2))\nprint(np.linalg.norm(pivoted_A - QR, ord=2))'

# %%
'''OLD QR, DISREGARD, ONLY FOR REFERENCE'''

'''def RRQR(A, TOL=None):
    qr_A = scipy.qr(A, pivoting=True)
    Q = qr_A[0]
    R = qr_A[1]
    
    k = 
    if TOL == None:
        TOL = np.linalg.norm(A, ord=2)/5
    M = R[0][0]
    N = Q[0][0]
    norm_A = np.linalg.norm(A, ord=2)
    norm_MN = abs(R[0][0]) * abs(Q[0][0])
    while abs(norm_A - norm_MN) > TOL and k<min(len(A), len(A[0])):
        k += 1
        M = R[:k,:k]
        N = Q[:k,:k]
        norm_MN = np.linalg.norm(M, ord=2) * np.linalg.norm(N, ord=2)
    
    new_Q = Q[:len(A)][:k]        
    return new_Q,M,k

Q,R,k = RRQR(A_100, None)
print(k)
Q,R,k = RRQR(S_100, None)
print(k)'''
# Out:
# 'def RRQR(A, TOL=None):\n    qr_A = scipy.qr(A, pivoting=True)\n    Q = qr_A[0]\n    R = qr_A[1]\n    \n    k = 1\n    if TOL == None:\n        TOL = np.linalg.norm(A, ord=2)/5\n    M = R[0][0]\n    N = Q[0][0]\n    norm_A = np.linalg.norm(A, ord=2)\n    norm_MN = abs(R[0][0]) * abs(Q[0][0])\n    while abs(norm_A - norm_MN) > TOL and k<min(len(A), len(A[0])):\n        k += 1\n        M = R[:k,:k]\n        N = Q[:k,:k]\n        norm_MN = np.linalg.norm(M, ord=2) * np.linalg.norm(N, ord=2)\n    \n    new_Q = Q[:len(A)][:k]        \n    return new_Q,M,k\n\nQ,R,k = RRQR(A_100, None)\nprint(k)\nQ,R,k = RRQR(S_100, None)\nprint(k)'

# %%
A = new_rand_A(100,95)

# %%
def RRQR(A, TOL=None):
    Q,R,p = scipy.qr(A, pivoting=True)          #get qr decomposition with pivoting from scipy
    pivoted_A = pivot_A(A,p)                    #pivot columns of A based on QR decomp
    k = 1                                       #starting rank = 1
    r_1 = R[0,:]                                #starting slices of the QR decomp, not important just for reference
    r_11 = R[0,0]
    r_22 = R[1:,1:]
    q_1 = Q[:,0]
    q_2 = Q[:,1:]
    
    '''test_r = np.zeros((2,len(R[0])))
    test_q = np.zeros((len(Q), 2))
    
    for i in range(len(R[0])):
        test_r[0][i] = R[0][i]
        test_r[1][i] = R[1][i]
        
    for i in range(len(Q)):
        test_q[i][0] = Q[i][0]
        test_q[i][1] = Q[i][1]
        
    print(test_r, test_q)
    
    
    print(np.linalg.norm(pivoted_A - np.matmul(test_q, test_r), ord=2))'''
    
    if TOL == None:                             #arbitrary tolerance if none is given
        TOL = 10e-5
    
    err = np.linalg.norm(r_22, ord=2)           #error is equal to norm of the part of the approximated matrix that is not used
    while err > TOL and k<min(len(A), len(A[0])):
        print("current error", err)                              #while error is greater than tolerance, increase
        k += 1                                  #increase rank
        
        r_1 = R[:k,:]                           #update slices
        r_11 = R[:k,:k]
        r_22 = R[k:,k:]
        q_1 = Q[:,:k]
        q_2 = Q[:,k:]
        
        if len(r_11[0]) == len(R[0]):           #if approximate array is max length of R, can't update error
            None
        else:
            err = np.linalg.norm(r_22, ord=2)
    
    return k

k = RRQR(A, None)
print("estimated rank",k)
print("actual rank", np.linalg.matrix_rank(A))
'''Q,R,k = RRQR(S_100, None)
print(k)'''
# Out:
# current error 97.24888941523507
# current error 96.56071643782268
# current error 96.08526108192986
# current error 95.98853931206972
# current error 95.7839620637274
# current error 95.77578915194292
# current error 94.85836190140265
# current error 92.67736515463444
# current error 92.53929334004256
# current error 92.42007557649261
# current error 89.93099544648018
# current error 89.53830538333041
# current error 88.26901845905195
# current error 87.7255898320288
# current error 87.68642941535053
# current error 87.00511905054664
# current error 86.93591832440889
# current error 86.24530131080104
# current error 85.59921604657114
# current error 85.59769866976309
# current error 85.46988886523471
# current error 85.4615079681315
# current error 85.45534291683435
# current error 83.91783365478838
# current error 82.98302314524896
# current error 82.67679577826652
# current error 82.56587732640398
# current error 82.54729990511233
# current error 82.52337730483221
# current error 82.35735683277144
# current error 78.65404147149461
# current error 78.65124721748003
# current error 77.59405641050027
# current error 77.1718296309721
# current error 76.71724882693073
# current error 76.71369138541749
# current error 76.29598940611137
# current error 76.29583675831617
# current error 76.27306196608629
# current error 76.16765793933448
# current error 75.21826277047204
# current error 74.76513451964401
# current error 71.68298982789867
# current error 69.96582864842921
# current error 67.31445749319865
# current error 66.15285040218185
# current error 65.97909485012899
# current error 63.967008240027404
# current error 63.960335402544594
# current error 63.84085671366761
# current error 63.6926681628148
# current error 63.45634756612263
# current error 62.428852982280866
# current error 61.641896877628234
# current error 61.63070598657813
# current error 61.559398164072135
# current error 61.130354256092424
# current error 60.08333734350435
# current error 59.96032148534297
# current error 54.0045602024632
# current error 53.8235552301285
# current error 53.69506397128499
# current error 51.638228570896494
# current error 51.62523784345827
# current error 51.27479969142122
# current error 49.83057480716015
# current error 49.799320665506265
# current error 49.51365041005843
# current error 48.01809469082032
# current error 44.72359706238847
# current error 44.51770353907326
# current error 43.970165317869544
# current error 40.80678435379472
# current error 40.256268345704534
# current error 39.87577609800629
# current error 37.536780534869926
# current error 37.536761734228406
# current error 37.501749330002816
# current error 35.913459041464385
# current error 34.743315074418895
# current error 30.31965716981878
# current error 28.720242841122285
# current error 25.724877527880544
# current error 25.081343320630694
# current error 23.304155194666922
# current error 22.400999788102666
# current error 22.395146288689563
# current error 19.668228870928875
# current error 18.920883121343252
# current error 16.136088113377728
# current error 16.131717400059156
# current error 13.754196827071342
# current error 8.53810959482571
# current error 6.164252839509543
# estimated rank 95
# actual rank 95
# 'Q,R,k = RRQR(S_100, None)\nprint(k)'
